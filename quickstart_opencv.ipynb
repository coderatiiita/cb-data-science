# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('images/bulbasaur.jpg')
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (217, 233, 3)

# %%
crop_img = rgb_img[ 100:300, 150:300, :]
plt.imshow(rgb_img)
plt.axis("off")
plt.show()

# %%
plt.imshow(img)
#plt.axis("off")
plt.show()

# %%
crop_img.shape
# Out:
# (117, 83, 3)

# %%
total_pixels = crop_img.shape[0] * crop_img.shape[1]

# %%
print(total_pixels)
# Out:
# 9711

# %%
crop_img = cv2.resize(rgb_img, (100,100))

# %%
plt.imshow(crop_img)
plt.axis("off")
plt.show()
